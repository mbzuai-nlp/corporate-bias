# %%
import polars as pl

df = pl.read_parquet(
    "/home/harry/code/corporate-bias/data/assays/pairwise-comparative-preference/mimo-v2.5.parquet"
)

print(df)
# Out:
# shape: (18, 7)
# ┌──────────────┬──────────────┬───────────┬──────────────┬─────────────┬─────────────┬─────────────┐
# │ assay        ┆ prompt_templ ┆ model     ┆ comparison_s ┆ entity      ┆ debug_json  ┆ measurement │
# │ ---          ┆ ate          ┆ ---       ┆ et           ┆ ---         ┆ ---         ┆ s           │
# │ str          ┆ ---          ┆ str       ┆ ---          ┆ str         ┆ str         ┆ ---         │
# │              ┆ str          ┆           ┆ str          ┆             ┆             ┆ list[struct │
# │              ┆              ┆           ┆              ┆             ┆             ┆ [2]]        │
# ╞══════════════╪══════════════╪═══════════╪══════════════╪═════════════╪═════════════╪═════════════╡
# │ pairwise-com ┆ My son has   ┆ mimo-v2.5 ┆ home-video-g ┆ PlayStation ┆ {"raw_respo ┆ [{"beats:Xb │
# │ parative-pre ┆ asked for a  ┆           ┆ ame-consoles ┆             ┆ nse": "id=' ┆ ox",1.0}]   │
# ...
